# %%
import os, ssl
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and
    getattr(ssl, '_create_unverified_context', None)):
    ssl._create_default_https_context = ssl._create_unverified_context

# Use pandas and numpy for csv loading and analysis
import pandas as pd
import numpy as np

# Re for matching strings
import string
import re

# Visualization tools
import seaborn as sns
import matplotlib.pyplot as plt

# NLTK module to do text analysis
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('punkt')
from nltk.corpus import PlaintextCorpusReader
nltk.download('wordnet')
from nltk.corpus import wordnet
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.text import Text
from nltk.stem.porter import PorterStemmer
from nltk.probability import FreqDist
nltk.download('averaged_perceptron_tagger')
from nltk.tag import pos_tag
nltk.download('tagsets')
from nltk.draw.dispersion import dispersion_plot as displt
# Out:
# [nltk_data] Downloading package punkt to /Users/halcyon/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/halcyon/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/halcyon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/halcyon/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets to /Users/halcyon/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!

# %%
# read the inventory csv as dataframe
df = pd.read_csv('/Users/halcyon/Desktop/Data Science for Design/NLS/nls-text-spiritualistNewspaper/spiritualistNewspaper-inventory.csv', header=None, names=['fileid', 'title'])

# %%
# expand the collum width to show complete data
pd.set_option('display.max_colwidth', 150)
df['title'] = df['title'].replace('Volume 21. ', '')
df.tail()
# Out:
#             fileid                                                    title
# 411  136346235.txt   Spiritualist newspaper - No.412, July 16th 1880 - P.20
# 412  136346236.txt   Spiritualist newspaper - No.413, July 23rd 1880 - P.20
# 413  136346237.txt   Spiritualist newspaper - No.414, July 30th 1880 - P.20
# 414  136346239.txt  Psyche - Volume 21, No.493, March 1882 - K.77.a.7(2)PER
# 415  136346240.txt    Psyche - Volume 21, No.493, May 1882 - K.77.a.7(2)PER

# %%
titles = list(df['title'])
month = []
year = []
for title in titles:
    yr = int((re.search('\d{4}', title))[0]) # Use regular expression to match the format of 4 consecutive digits as year
    year += [yr]
    allMonths = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    title_list = title.split(' ')
    for i in title_list:
        if i in allMonths:  # Use the list of allMonths to match month
            month.append(i)
# print(month[:5])
# print(year[:5])

# %%
df['year'] = year
df['month'] = month
df.head()

fileids = list(df['fileid'])
titles = list(df['title'])
inventory = dict(zip(fileids, titles))
# print(inventory)

# %%
df[df.fileid.isin(["135908626.txt"])]
# Out:
#           fileid                                        title  year month
# 9  135908626.txt  Spiritualist - No.10, June 15th 1870 - P.20  1870  June

# %%
df.to_csv('data-fileid-year.csv')

# %%
sns.set_style("whitegrid")
yearCount = sns.countplot(y=df.year, palette="flare")
yearCount.set_title("Yearly Distribution of the Spiritualist Newspaper")

# plt.show()
# Out:
# Text(0.5, 1.0, 'Yearly Distribution of the Spiritualist Newspaper')

# %%
yearCount = sns.countplot(y=df.month, palette="flare")
yearCount.set_title("Monthly Distribution of the Spiritualist Newspaper")

# plt.show()
# Out:
# Text(0.5, 1.0, 'Monthly Distribution of the Spiritualist Newspaper')

# %%
corpus_folder = '/Users/halcyon/Desktop/Data Science for Design/NLS/nls-text-spiritualistNewspaper'
wordlists = PlaintextCorpusReader(corpus_folder, '\d.*')
corpus_tokens = wordlists.words()

# %%
def getWordsSents(plaintext_corpus_read_lists):
    all_words = []
    all_words_lower = []
    all_sents = []
    for fileid in fileids:
        # fileids is the sorted list of name in the dataframe
        file_words = plaintext_corpus_read_lists.words(fileid)
        all_words_lower += [str(word).lower() for word in file_words if word.isalpha()]
        all_words += [str(word) for word in file_words if word.isalpha()]
        file_sents = sent_tokenize(plaintext_corpus_read_lists.raw(fileid))
        all_sents += [str(sent) for sent in file_sents]
        # .sents(fileid) returns strings
        # sent_tokenize is also part of the nltk tools
    return all_words, all_words_lower, all_sents

# %%
spiritualist_words, spiritualist_words_lower, spiritualist_sents = getWordsSents(wordlists)

# %%
isWord = re.compile('[a-zA-z.]+')

# %%
def removeNonEnglishWords(list_of_strings):
    english_only = []
    nonenglish = []
    for s in list_of_strings:
        test = isWord.match(s)  # fails if has characters other than letters or a period
        if (test != None):
            passed = test.group()  # get the matching string
            if wordnet.synsets(passed):  # see if WordNet recognizes the matching string
                english_only.append(passed)
            else:
                nonenglish.append(passed)
        else:
            nonenglish.append(passed)
    return english_only, nonenglish

# %%
recognised, unrecognised = removeNonEnglishWords(spiritualist_words)

# %%
# Filter common english stop words and meaningless words that occur frequently
to_exclude = set(stopwords.words('english') + list(string.punctuation) + list(string.digits) + ['also', 'per', '000', 'one', 'many', 'may', 'two', 'see','would','every','could'])

# Short words within the length of 2 are often OCR errors or meaningless words, filter them as well
filtered_lower = [w for w in spiritualist_words_lower if (len(w) > 2 and not w in to_exclude)]

# %%
fdist_filtered_lower = FreqDist(filtered_lower) # Calculate words frequent distribution
print("Total words after filtering:", fdist_filtered_lower.N())
print("50 most common words after filtering:", fdist_filtered_lower.most_common(100))
# Out:
# Total words after filtering: 5594170
# 50 most common words after filtering: [('spirit', 30004), ('spiritualism', 29581), ('mrs', 23471), ('street', 23386), ('london', 19819), ('medium', 18585), ('spiritualist', 18082), ('time', 17633), ('upon', 16414), ('great', 16221), ('life', 16184), ('esq', 16120), ('spiritual', 15904), ('spirits', 15504), ('man', 14220), ('phenomena', 14014), ('spiritualists', 13590), ('said', 13226), ('new', 11974), ('association', 11905), ('well', 11745), ('first', 11580), ('present', 11577), ('given', 11447), ('road', 11257), ('made', 10801), ('world', 10613), ('miss', 10265), ('society', 10164), ('table', 9782), ('place', 9730), ('without', 9702), ('much', 9671), ('work', 9644), ('good', 9528), ('years', 9193), ('book', 9135), ('light', 9086), ('published', 8908), ('manifestations', 8723), ('facts', 8689), ('last', 8677), ('power', 8550), ('like', 8397), ('hand', 8271), ('price', 8191), ('nature', 8178), ('little', 8090), ('room', 8070), ('public', 8054), ('free', 8027), ('subject', 7994), ('must', 7965), ('men', 7950), ('three', 7881), ('john', 7726), ('say', 7517), ('office', 7391), ('mediums', 7338), ('science', 7337), ('members', 7335), ('house', 7333), ('body', 7307), ('found', 7300), ('hands', 7085), ('give', 7050), ('state', 7012), ('mediumship', 6912), ('know', 6876), ('day', 6807), ('seances', 6736), ('post', 6696), ('mind', 6692), ('god', 6656), ('author', 6633), ('newspaper', 6534), ('truth', 6437), ('another', 6416), ('seen', 6380), ('never', 6338), ('matter', 6317), ('persons', 6284), ('shall', 6271), ('committee', 6260), ('known', 6238), ('form', 6224), ('evening', 6188), ('come', 6160), ('way', 6137), ('william', 6128), ('thought', 6110), ('seance', 6099), ('make', 6049), ('following', 5991), ('evidence', 5983), ('part', 5970), ('held', 5947), ('others', 5936), ('home', 5895), ('friends', 5887)]

# %%
fdist_filtered_lower = FreqDist(filtered_lower)
plt.figure(figsize = (15, 10))
plt.rc('font', size=12)
number_of_tokens = 20 # indicate number of the most frequently occured words
fdist_filtered_lower.plot(number_of_tokens, title='Frequency Distribution for ' + str(number_of_tokens) + ' Most Common Tokens in the Standardised Spiritualist Dataset (excluding stop words)')
# Out:
# <AxesSubplot:title={'center':'Frequency Distribution for 20 Most Common Tokens in the Standardised Spiritualist Dataset (excluding stop words)'}, xlabel='Samples', ylabel='Counts'>

# %%
corpus_text = Text(spiritualist_words)
targetCity = ['London', 'Birmingham', 'Glasgow','Liverpool', 'Bristol', 'Sheffield', 'Manchester', 'Leeds','Edinburgh','Lecester','Bradford','Cardiff']
plt.figure(figsize=(18,10))
plt.rc('font', size=12)
displt(corpus_text, targetCity, ignore_case=True, title='Lexical Dispersion Plot of Top 12 Major Cities in Spiritualist Newspaper Dataset')

# %%
year_to_fileid = df.groupby('year')['fileid'].apply(list).to_dict()

# %%
def getTokens(plaintext_corpus_read_lists, year_files):
    all_words = []
    for fileid in year_files:
        file_words = plaintext_corpus_read_lists.words(fileid)
        all_words += [str(word) for word in file_words if word.isalpha()]
    return all_words

# %%
year_to_tokens = {}
for ye in year_to_fileid.keys():
    year_to_tokens['list_' + str(ye)] = getTokens(wordlists, year_to_fileid[ye])

# %%
print(year_to_tokens["list_1876"][:100])
# Out:
# ['llff', 'J', 'l', 'V', 'Ofj', 'd', 'I', 'CIjjj', 'Olb', 'st', 'llttospapr', 'rmT', 'e', 'deb', 'ioit', 'priixmlism', 'xtt', 'eitt', 'xifixht', 'Mintf', 'f', 'No', 'VOL', 'vm', 'No', 'i', 'LQNDQK', 'ERIDAY', 'JANUARY', 'waSSS', 't', 'Published', 'Weekly', 'Price', 'Twopfencaj', 'Contents', 'The', 'Necessity', 'for', 'Mesmeric', 'Experiments', 'in', 'Spiritualism', 'A', 'Haunted', 'House', 'i', 'V', 'kSIsZ', 'u', 'Spirit', 'Teachings', 'No', 'XL', 'v', 'The', 'Prince', 'of', 'Wales', 'among', 'the', 'Ihdiau', 'Jugglers', 'v', 'What', 'is', 'Magic', 'Physical', 'Manifestations', 'among', 'the', 'Greeks', 'and', 'Romans', 'Promised', 'Experiments', 'in', 'Magic', 'Spiritualism', 'in', 'South', 'Africa', 'v', 'c', 'i', 'j', 'Taking', 'Casts', 'of', 'Materialised', 'Spirit', 'Hands', 'The', 'Oracle', 'of', 'the', 'Dead', 'in', 'Thesprotia', 'By']

# %%
targets = ['son','daughter','mother','father','cousin']

# %%
def wordOccurrenceByYear(word):
    word_occurs = []
    for tokens in year_to_tokens.values(): 
        word_count_capital = tokens.count(word)
        word_lower = word.lower()
        word_count_lower = tokens.count(word_lower)
        total_words = len(tokens)
        occurrence = (word_count_capital + word_count_lower)/total_words
        word_occurs += [occurrence]
    return word_occurs

# %%
son = wordOccurrenceByYear('son')
daughter = wordOccurrenceByYear('daughter')
father = wordOccurrenceByYear('father')
mother = wordOccurrenceByYear('mother')

# %%
Mon = wordOccurrenceByYear('Monday')
Tue = wordOccurrenceByYear('Tuesday')
Wed = wordOccurrenceByYear('Wednesday')
Thu = wordOccurrenceByYear('Thursday')
Fri = wordOccurrenceByYear('Friday')
Sat = wordOccurrenceByYear('Saturday')
Sun = wordOccurrenceByYear('Sunday')

# %%
def wordCountByYear(word):
    word_count = []
    for tokens in year_to_tokens.values():
        word_count_capital = tokens.count(word)
        word_lower = word.lower()
        word_count_lower = tokens.count(word_lower)
        total_count = word_count_capital + word_count_lower
        word_count += [total_count]
    return word_count

# %%
murder = wordCountByYear('murder')
suicide = wordCountByYear('suicide')
illness = wordCountByYear('illness')

# %%
col_names = ['1869', '1870', '1871', '1872', '1873', '1874', '1875', '1876', '1877', '1878', '1879', '1880', '1882']
row_names = ['son','daughter','father','mother','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday','murder','suicide','illness']
year_df = pd.DataFrame(data=[son,daughter,father,mother,Mon,Tue,Wed,Thu,Fri,Sat,Sun,murder,suicide, illness], columns=col_names, index=row_names)

# %%
year_df = year_df.T
print(year_df.head())
year_df.to_csv('data-family-weekday-death.csv')
# Out:
#            son  daughter    father    mother    Monday   Tuesday  Wednesday  \
# 1869  0.000384  0.000192  0.000664  0.000804  0.000017  0.000122   0.000061
# 1870  0.000311  0.000113  0.000436  0.000382  0.000090  0.000057   0.000075
# 1871  0.000188  0.000206  0.000418  0.000418  0.000088  0.000051   0.000085
# 1872  0.000312  0.000215  0.000339  0.000485  0.000065  0.000081   0.000046
# 1873  0.000210  0.000161  0.000275  0.000368  0.000125  0.000090   0.000142
#
#       Thursday    Friday  Saturday    Sunday  murder  suicide  illness
# 1869  0.000079  0.000166  0.000070  0.000157    14.0      2.0      2.0
# 1870  0.000108  0.000134  0.000116  0.000302    14.0      4.0     24.0
# 1871  0.000103  0.000094  0.000079  0.000188     2.0      6.0     18.0
# 1872  0.000129  0.000092  0.000124  0.000124    26.0     20.0     16.0
# 1873  0.000253  0.000097  0.000091  0.000290    14.0      8.0     32.0

# %%
t = Text(corpus_tokens)
t.concordance("edinburgh")
# Out:
# Displaying 25 of 676 matches:
#  . ANSWEES TO COEEESPONDENTS . B . Edinburgh . Evidence is best obtained by ind
# nd perhaps you find it the same in Edinburgh . We thank you for your good wishe
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kilmorey - h
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kilmorey - h
# e last few weeks the University of Edinburgh has opened its doors to ladies who
# ssociated with the great school of Edinburgh are now as freely at the disposal
# been gained at the Universities of Edinburgh Paris Zurich and some other places
# ert Chambers Esq . St . Andrew ' s Edinburgh H . D . Jencken Esq . Kilmorey - h
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kihnorey - h
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kilmorey - h
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kilmbrey - h
#  life and are full of expression . Edinburgh Edmonston and Douglas . 1869 . t T
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kilmorey - h
# ast month visited both Glasgow and Edinburgh where his public readings and priv
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kilmorey - h
# obert Chambers Esq . St . Andrew s Edinburgh H . H . Jencken Esq . Kihnorey - h
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kilmorey - h
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kilmorey - h
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kilmorey - h
# many of the most noted citizens of Edinburgh who witnessed our - joint experime
# mbers and Professor Balfour of the Edinburgh University who kindly introduced m
# d patients in the Lock Hospital at Edinburgh of which he was at that time super
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kilmorey - h
# obert Chambers Esq . St . Andrew s Edinburgh H . D . Jencken Esq . Kilmorey - h
# ying at an hotel some years ago in Edinburgh I made the acquaintance there of a

# %%
bigrams_words = nltk.bigrams(filtered_lower)
cfd = nltk.ConditionalFreqDist(bigrams_words)
fd = cfd['medium']
fd.plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
print(fd)
# Out:
# <FreqDist with 3734 samples and 18585 outcomes>

# %%
finder=nltk.collocations.BigramCollocationFinder.from_words(filtered_lower)
t1 = sorted(finder.ngram_fd.items(), key=lambda t: (-t[1], t[0]))[:2000]

# %%
finder_tri=nltk.collocations.TrigramCollocationFinder.from_words(filtered_lower)
t2 = sorted(finder_tri.ngram_fd.items(), key=lambda t: (-t[1], t[0]))[:2000]

# %%
tups = {x[0] for x in t2}
[(x,y,z) for x,y,z in tups if x == "medium" or y == "medium" or z == "medium"]
# Out:
# [('medium', 'raps', 'home'),
#  ('professional', 'medium', 'present'),
#  ('next', 'ask', 'medium'),
#  ('professional', 'medium', 'published'),
#  ('medium', 'home', 'daily'),
#  ('spiritualist', 'good', 'medium'),
#  ('medium', 'published', 'report'),
#  ('good', 'medium', 'advertisements'),
#  ('services', 'professional', 'medium'),
#  ('spiritualist', 'professional', 'medium'),
#  ('medium', 'advertisements', 'circulates'),
#  ('charles', 'williams', 'medium'),
#  ('huet', 'good', 'medium'),
#  ('good', 'medium', 'raps'),
#  ('williams', 'medium', 'home')]

# %%
tups1 = {x[0] for x in t1}
[(x,y) for x,y in tups1 if x == "medium" or y == "medium"]
# Out:
# [('good', 'medium'),
#  ('physical', 'medium'),
#  ('medium', 'ship'),
#  ('test', 'medium'),
#  ('professional', 'medium'),
#  ('medium', 'raps'),
#  ('trance', 'medium'),
#  ('medium', 'advertisements'),
#  ('medium', 'home'),
#  ('writing', 'medium'),
#  ('williams', 'medium'),
#  ('medium', 'present'),
#  ('healing', 'medium'),
#  ('medium', 'usually'),
#  ('spirit', 'medium')]

# %%
[(x,y,z) for x,y,z in tups if x == "apparition" or y == "apparition" or z == "apparition"]
# Out:
# [('apparition', 'seen', 'ancestors'), ('account', 'apparition', 'seen')]

# %%
[(x,y,z) for x,y,z in tups if x == "healing" or y == "healing" or z == "healing"]
# Out:
# []

# %%
# t.concordance("divorce", lines = 50)

# %%
# son = wordOccurrenceByYear('son')

# %%
mrs = wordOccurrenceByYear('Mrs')
miss = wordOccurrenceByYear('Miss')
divorce = wordOccurrenceByYear('divorce')

# %%
rogers = wordCountByYear('Rogers')
eglinton = wordCountByYear('Eglinton')
weldon = wordCountByYear('Weldon') 
wilkinson = wordCountByYear('Wilkinson')
wallace = wordCountByYear('Wallace')
dale = wordCountByYear('Dale')
crookes = wordCountByYear('Crookes')
cook = wordCountByYear('Cook')

# %%
col_names = ['1869', '1870', '1871', '1872', '1873', '1874', '1875', '1876', '1877', '1878', '1879', '1880', '1882']
row_names = ['Mrs','Miss','divorce','Rogers','Eglinton','Weldon','Wilkinson']
name_df = pd.DataFrame(data=[mrs, miss, divorce, rogers, eglinton, weldon, wilkinson], columns=col_names, index=row_names)

# %%
name_df = name_df.T
print(name_df.head())
name_df.to_csv('data-names-stories.csv')
# Out:
#            Mrs      Miss   divorce  Rogers  Eglinton  Weldon  Wilkinson
# 1869  0.001031  0.000201  0.000000     0.0       0.0     0.0       17.0
# 1870  0.001421  0.000379  0.000006     7.0       0.0     1.0       27.0
# 1871  0.001782  0.000469  0.000012     6.0       0.0     0.0       50.0
# 1872  0.001411  0.001118  0.000000    17.0       0.0     0.0       28.0
# 1873  0.001494  0.000999  0.000003    37.0       0.0     0.0        4.0

# %%
col_names = ['1869', '1870', '1871', '1872', '1873', '1874', '1875', '1876', '1877', '1878', '1879', '1880', '
# [(('national', 'association'), 4699), (('spiritualist', 'newspaper'), 4506), (('russell', 'street'), 4443), (('association', 'spiritualists'), 4061), (('post', 'free'), 3805), (('great', 'russell'), 3597), (('branch', 'office'), 3483), (('new', 'york'), 3316), (('newspaper', 'branch'), 3298), (('street', 'london'), 3203), (('british', 'national'), 2733), (('modern', 'spiritualism'), 2297), (('maria', 'lane'), 2196), (('ave', 'maria'), 2136), (('psychological', 'society'), 2041), (('well', 'known'), 1977), (('fruit', 'salt'), 1863), (('street', 'bloomsbury'), 1663), (('dale', 'owen'), 1623), (('allen', 'ave'), 1617), (('years', 'ago'), 1594), (('phenomena', 'spiritualism'), 1473), (('price', 'post'), 1414), (('spiritual', 'phenomena'), 1392), (('epes', 'sargent'), 1366), (('united', 'states'), 1356), (('spirit', 'world'), 1321), (('miss', 'cook'), 1270), (('serjeant', 'cox'), 1268), (('fitz', 'gerald'), 1257), (('spirit', 'circles'), 1256), (('robert', 'dale'), 1227), (('museum', 'street'), 1184), (('barrister', 'law'), 1175), (('took', 'place'), 1151), (('bloomsbury', 'london'), 1069), (('lizzie', 'doten'), 1062), (('road', 'dalston'), 1055), (('miss', 'kislingbury'), 1054), (('street', 'philadelphia'), 1034), (('john', 'king'), 1000), (('william', 'crookes'), 996), (('montgomery', 'place'), 963), (('buda', 'pesth'), 955), (('physical', 'phenomena'), 950), (('dialectical', 'society'), 947), (('carter', 'blake'), 934), (('united', 'kingdom'), 928), (('spiritual', 'manifestations'), 925), (('five', 'shillings'), 921), (('published', 'weekly'), 908), (('maurice', 'davies'), 906), (('great', 'britain'), 897), (('mrs', 'weldon'), 885), (('british', 'museum'), 881), (('post', 'office'), 881), (('eno', 'fruit'), 875), (('square', 'london'), 867), (('red', 'edges'), 851), (('allan', 'kardec'), 849), (('honorary', 'secretary'), 845), (('given', 'mediumship'), 836), (('office', 'great'), 835), (('lane', 'london'), 832), (('dalston', 'association'), 829), (('william', 'denton'), 827), (('well', 'authenticated'), 823), (('london', 'spiritualist'), 816), (('trance', 'medium'), 814), (('sunday', 'evening'), 810), (('sir', 'charles'), 807), (('makdougall', 'gregory'), 804), (('road', 'brixton'), 800), (('banner', 'light'), 795), (('gerald', 'massey'), 782), (('last', 'week'), 773), (('private', 'seances'), 771), (('spirit', 'life'), 770), (('mrs', 'makdougall'), 767), (('esq', 'mrs'), 764), (('rev', 'maurice'), 763), (('cloth', 'red'), 758), (('place', 'boston'), 745), (('thursday', 'evening'), 745), (('lazy', 'lays'), 744), (('trance', 'mediumship'), 735), (('physical', 'manifestations'), 732), (('algernon', 'joy'), 728), (('von', 'vay'), 727), (('william', 'harrison'), 725), (('present', 'time'), 724), (('men', 'science'), 722), (('harrison', 'great'), 716), (('cora', 'tappan'), 713), (('take', 'place'), 713), (('benjamin', 'coleman'), 711), (('london', 'price'), 710), (('members', 'circle'), 697), (('short', 'time'), 689), (('inner', 'life'), 684), (('inquirers', 'spiritualism'), 684), (('future', 'life'), 683), (('upper', 'norwood'), 678), (('given', 'trance'), 677), (('reading', 'room'), 674), (('hon', 'sec'), 673), (('animal', 'magnetism'), 667), (('san', 'francisco'), 665), (('personal', 'experiences'), 664), (('mesmeric', 'sleep'), 662), (('anna', 'blackwell'), 660), (('florence', 'marryat'), 659), (('london', 'published'), 659), (('rue', 'lille'), 645), (('british', 'association'), 638), (('spiritualists', 'great'), 637), (('charles', 'blackburn'), 634), (('scientific', 'men'), 631), (('form', 'spirit'), 630), (('ladies', 'gentlemen'), 628), (('baroness', 'adelma'), 620), (('judge', 'edmonds'), 619), (('park', 'road'), 617), (('given', 'spirits'), 599), (('hudson', 'tuttle'), 599), (('several', 'times'), 593), (('twenty', 'years'), 591), (('minister', 'court'), 590), (('test', 'conditions'), 590), (('mediumship', 'mrs'), 585), (('american', 'minister'), 584), (('men', 'women'), 584), (('office', 'british'), 584), (('james', 'wason') ...

# %%
print(t2)
# Out:
# [(('national', 'association', 'spiritualists'), 3651), (('great', 'russell', 'street'), 3441), (('newspaper', 'branch', 'office'), 3248), (('spiritualist', 'newspaper', 'branch'), 3179), (('british', 'national', 'association'), 2599), (('ave', 'maria', 'lane'), 2071), (('allen', 'ave', 'maria'), 1580), (('price', 'post', 'free'), 1346), (('russell', 'street', 'bloomsbury'), 1246), (('russell', 'street', 'london'), 1216), (('robert', 'dale', 'owen'), 1208), (('museum', 'street', 'london'), 1108), (('street', 'bloomsbury', 'london'), 877), (('eno', 'fruit', 'salt'), 869), (('cloth', 'red', 'edges'), 750), (('office', 'great', 'russell'), 719), (('rev', 'maurice', 'davies'), 718), (('maria', 'lane', 'london'), 702), (('branch', 'office', 'great'), 697), (('montgomery', 'place', 'boston'), 690), (('harrison', 'great', 'russell'), 628), (('british', 'museum', 'street'), 624), (('given', 'trance', 'mediumship'), 610), (('mrs', 'makdougall', 'gregory'), 609), (('london', 'spiritualist', 'newspaper'), 596), (('branch', 'office', 'british'), 573), (('form', 'spirit', 'circles'), 566), (('formerly', 'american', 'minister'), 565), (('american', 'minister', 'court'), 560), (('hon', 'robert', 'dale'), 558), (('published', 'weekly', 'price'), 554), (('office', 'british', 'museum'), 549), (('mediumship', 'lizzie', 'doten'), 548), (('weekly', 'price', 'twopence'), 522), (('association', 'spiritualists', 'great'), 506), (('brixton', 'psychological', 'society'), 496), (('spiritualists', 'great', 'russell'), 496), (('navarino', 'road', 'dalston'), 494), (('liverpool', 'psychological', 'society'), 493), (('prince', 'emile', 'sayn'), 482), (('post', 'free', 'cloth'), 481), (('physical', 'phenomena', 'spiritualism'), 477), (('association', 'inquirers', 'spiritualism'), 464), (('erzherzog', 'alexander', 'gasse'), 462), (('branch', 'office', 'london'), 459), (('russian', 'imperial', 'councillor'), 454), (('society', 'great', 'britain'), 454), (('sir', 'charles', 'isham'), 452), (('psychological', 'society', 'great'), 451), (('russell', 'street', 'melbourne'), 451), (('road', 'north', 'brixton'), 449), (('melbourne', 'victoria', 'australia'), 448), (('fitz', 'gerald', 'mrs'), 446), (('price', 'five', 'shillings'), 444), (('three', 'signals', 'given'), 443), (('emile', 'sayn', 'wittgenstein'), 442), (('maria', 'lane', 'paul'), 442), (('london', 'allen', 'ave'), 440), (('loughborough', 'road', 'north'), 439), (('lamb', 'conduit', 'street'), 437), (('esq', 'montgomery', 'place'), 436), (('religio', 'philosophical', 'journal'), 432), (('quarterly', 'journal', 'science'), 431), (('street', 'london', 'price'), 427), (('post', 'free', 'spiritualist'), 418), (('work', 'ever', 'published'), 418), (('elms', 'john', 'road'), 406), (('miss', 'anna', 'blackwell'), 406), (('charles', 'isham', 'bart'), 405), (('john', 'road', 'brixton'), 404), (('red', 'edges', 'price'), 402), (('post', 'office', 'orders'), 401), (('carter', 'blake', 'doc'), 398), (('rue', 'lille', 'paris'), 398), (('street', 'san', 'francisco'), 397), (('well', 'written', 'little'), 395), (('english', 'speaking', 'countries'), 393), (('lane', 'paul', 'churchyard'), 388), (('cottage', 'old', 'ford'), 386), (('street', 'grosvenor', 'square'), 385), (('blake', 'doc', 'sci'), 382), (('esq', 'hereford', 'square'), 382), (('office', 'museum', 'street'), 382), (('minister', 'court', 'naples'), 380), (('reading', 'room', 'library'), 380), (('buda', 'pesth', 'hungary'), 375), (('owen', 'formerly', 'american'), 375), (('dale', 'owen', 'formerly'), 374), (('poems', 'inner', 'life'), 373), (('association', 'enquirers', 'spiritualism'), 372), (('bar', 'george', 'martyr'), 369), (('terry', 'russell', 'street'), 369), (('reality', 'physical', 'phenomena'), 367), (('street', 'melbourne', 'victoria'), 367), (('published', 'allen', 'ave'), 366), (('buildings', 'chancery', 'lane'), 364), (('author', 'life', 'swedenborg'), 363), (('alfred', 'russell', 'wallace'), 362), (('society', 'hon', 'sec'), 362), (('dead', 'spir ...

# %%
t.concordance('crookes')
# Out:
# Displaying 25 of 2522 matches:
# xamination of the room c . MESSRS . CROOKES YARLEY ON SPIRITUALISM . Mr . Willi
# RLEY ON SPIRITUALISM . Mr . William Crookes F . R . S . has published an articl
# . tb which it has given rise . Mr . Crookes is the editor of the Chemical Nems
#  London the article written by Mr . Crookes is bringing him rather more unpopul
# nt known to modem science . As Mr . Crookes risks a present high reputation by
#  SPIRITUALIST . July 15 1870 . Mr . Crookes - says that some Spiritualists ascr
# Here is the article written by Mr . Crookes Some weeks ago the fact that I was
#  sent last Saturday to Mr . William Crookes F . R . S . and it was called forth
# th by the foregoing article by Mr . Crookes on Spiritualism To the Editor of th
# itor of the Spiritualist . Sir Mr . Crookes has sen me an article of his upon S
# wood House Beckenham Kent . William Crookes Esq . July 11 1870 . My Dear Sir I
#  violent I had taken the pre - Mr . Crookes omits to state that these lines are
#  their business and not ours . Mr . Crookes over - estimates the importance of
# o Fare you well I go I got MESSRS . CROOKES YARLEY OK SPIRITUALISM . Continued
# er has just been received from Mr . Crookes 20 Mornington - road N . W . July 1
# n sir your obedient servant William Crookes . The following is the reply of Mr
#  The following is the reply of Mr . Crookes to the letter from Mr . Varley 20 M
# y dear sir very truly yours William Crookes . DR . NEWTOFS HEALIKGr MEDIUMSHIP
# piritual Manifestations 81 Messrs . Crookes and Varley on Spiritualism 83 Leade
#  the tomb . Emma Tyndall . MR . W . CROOKES F . R . S . ON SPIRITUALISM . 20 Mo
# nquiry and that one is Mr . William Crookes F . R . S . He testifies that he is
# subject of future inquiry . As Mr . Crookes like some other scientific men migh
# body . However let that pass . Mr . Crookes has done more than several of his f
# s published a letter comparing Mr . Crookes to the Professor of Philosophy at P
#  so . This is not just because Mr . Crookes has not refused to observe Spiritua
